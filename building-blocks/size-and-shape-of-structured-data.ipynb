# %% [markdown]
# # The size and shape of a CSV file

# %% [markdown]
# <div class="alert alert-info"><img src="../images/hhicon.png" width="50px" style="vertical-align: bottom; margin-right: 10px;">Remember to run each cell using <b>Shift+Enter</b>!</div>

# %% [markdown]
# ## Opening a CSV file

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# Using Pandas we can open a CSV file from a url – no need to download it first. To begin with, we open the CSV file and give it the name `df` (for 'DataFrame').
#
# In this case, we're opening the [Brisbane Hospital registers of deaths 1899 to 1913](https://data.qld.gov.au/dataset/34ff0384-e09a-4ba0-8ea4-f54534e1aace) from the Queensland State Archives.

# %%
df = pd.read_csv('https://www.data.qld.gov.au/dataset/34ff0384-e09a-4ba0-8ea4-f54534e1aace/resource/265df65a-372e-4f90-a6b8-5a47c30fc740/download/brisbane-hospital-deaths-1899-1913.csv')

# %% [markdown]
# From now on we can just use `df` when we want to refer to the dataset.
#
# Pandas dataframes have lots of useful built-in tricks for exploring and analysing the dataset. We can use `.head()` to show us the first few rows.

# %%
df.head(400)
# Out:
#     Last name          Given names   Age    No. Date of death Prev sys  \
# 0      ABBOTT               Albert  47.0  146.0    1907-06-24  HOS1/18
# 1        ABEL         Adam Phillip  45.0  205.0    1913-08-04  HOS1/18
# 2        ABEL      Johanna Pauline  40.0  283.0    1907-11-19  HOS1/18
# 3     ABRAHAM               August  71.0  190.0    1912-07-09  HOS1/18
# 4     ABRAHAM               Kubeel  30.0  239.0    1906-11-27  HOS1/18
# ..        ...                  ...   ...    ...           ...      ...
# 395    BONNEY  Christopher Bertram  24.0   45.0    1912-02-04  HOS1/18
# 396    BONNEY         Thomas Edwin  60.0  240.0    1907-09-17  HOS1/18
# 397   BONNING      Catherine Maria  38.0   92.0    1900-06-10  HOS1/18
# 398    BONSER       William Edward  23.0  190.0    1909-07-24  HOS1/18
# 399      BONY               Joseph  64.0   82.0    1913-03-27  HOS1/18
#
#      Item ID Microfilm number                          Index name  \
# 0       2887            Z1168  Brisbane Hospital deaths 1899-1913
# 1       2887            Z1168  Brisbane Hospital deaths 1899-1913
# 2       2887            Z1168  Brisbane Hospital deaths 1899-1913
# 3       2887            Z1168  Brisbane Hospital deaths 1899-1913
# 4       2887            Z1168  Brisbane Hospital deaths 1899-1913
# ..       ...              ...                                 ...
# 395     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 396     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 397     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 398     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 399     2887            Z1168  Brisbane Hospital deaths 1899-1913
#
#                                            Description  \
# 0    Registers kept by the Brisbane Hospital record...
# 1    Registers kept by the Brisbane Hospital record...
# 2    Registers kept by the Brisbane Hospital record...
# 3    Registers kept by the Brisbane Hospital record...
# 4    Registers kept by the Brisbane Hospital record...
# ..                                                 ...
# 395  Registers kept by the Brisbane Hospital record...
# 396  Registers kept by the Brisbane Hospital record...
# 397  Registers kept by the Brisbane Hospital record...
# 398  Registers kept by the Brisbane Hospital record...
# 399  Registers kept by the Brisbane Hospital record...
#
#                                                 Source
# 0    http://www.archivessearch.qld.gov.au/Search/It...
# 1    http://www.archivessearch.qld.gov.au/Search/It...
# 2    http://www.archivessearch.qld.gov.au/Search/It...
# 3    http://www.archivessearch.qld.gov.au/Search/It...
# 4    http://www.archivessearch.qld.gov.au/Search/It...
# ..                                                 ...
# 395  http://www.archivessearch.qld.gov.au/Search/It...
# 396  http://www.archivessearch.qld.gov.au/Search/It...
# 397  http://www.archivessearch.qld.gov.au/Search/It...
# 398  http://www.archivessearch.qld.gov.au/Search/It...
# 399  http://www.archivessearch.qld.gov.au/Search/It...
#
# [400 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-info"><img src="../images/hhicon.png" width="50px" style="vertical-align: bottom; margin-right: 10px;">Try putting a number in the brackets after <code>.head</code>. What happens? (Remember to hit <b>Shift+Enter</b> to run the cell once you've changed it!)</div>

# %% [markdown]
# ## How big is the dataset?
#
# We can use `.shape` to give us the number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (4866, 11)

# %% [markdown]
# So this dataset has 4,866 rows.

# %% [markdown]
# ## Get the values of a single column

# %% [markdown]
# To get the values of a single column (what Pandas calls a 'series'), just supply the column name in square brackets.

# %%
df['Last name']
# Out:
# 0        ABBOTT
# 1          ABEL
# 2          ABEL
# 3       ABRAHAM
# 4       ABRAHAM
#          ...
# 4861    YOURELL
# 4862        YUE
# 4863    ZALLOTI
# 4864      ZERBE
# 4865    ZILLMAN
# Name: Last name, Length: 4866, dtype: object

# %% [markdown]
# Note that for ease of display, Pandas shows you just the first and last values.

# %% [markdown]
# ## Get the values of a single row
#
# Rows in a dataframe are indexed – they're the numbers you can see in the left hand column. You can access any row by supplying it's index number to `.iloc`.

# %%
df.iloc[4865]
# Out:
# Last name                                                     ZILLMAN
# Given names                                             James Rudolph
# Age                                                                44
# No.                                                                88
# Date of death                                              1905-04-09
# Prev sys                                                      HOS1/18
# Item ID                                                          2887
# Microfilm number                                                Z1168
# Index name                         Brisbane Hospital deaths 1899-1913
# Description         Registers kept by the Brisbane Hospital record...
# Source              http://www.archivessearch.qld.gov.au/Search/It...
# Name: 4865, dtype: object

# %% [markdown]
# <div class="alert alert-info"><img src="../images/hhicon.png" width="50px" style="vertical-align: bottom; margin-right: 10px;">Try changing the number in the square brackets! What happens?</div>

# %% [markdown]
# ## Get all the rows that match a particular value
#
# We can also supply conditions to `.iloc` to filter rows by a particular column and value. So to find all the rows where the `Last name` was 'ABRAHAM'...

# %%
# Out:
#      Last name             Given names   Age    No. Date of death Prev sys  \
# 2364      KING  John Robert Fitzgerald  40.0   74.0    1911-03-25  HOS1/18
# 2365      KING                     NaN   0.0  125.0    1910-06-04  HOS1/18
# 2366      KING                  George  37.0  138.0    1906-07-19  HOS1/18
# 2367      KING                   James  37.0  163.0    1907-07-16  HOS1/18
# 2368      KING               Frederick  42.0  204.0    1902-08-31  HOS1/18
#
#       Item ID Microfilm number                          Index name  \
# 2364     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 2365     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 2366     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 2367     2887            Z1168  Brisbane Hospital deaths 1899-1913
# 2368     2887            Z1168  Brisbane Hospital deaths 1899-1913
#
#                                             Description  \
# 2364  Registers kept by the Brisbane Hospital record...
# 2365  Registers kept by the Brisbane Hospital record...
# 2366  Registers kept by the Brisbane Hospital record...
# 2367  Registers kept by the Brisbane Hospital record...
# 2368  Registers kept by the Brisbane Hospital record...
#
#                                                  Source
# 2364  http://www.archivessearch.qld.gov.au/Search/It...
# 2365  http://www.archivessearch.qld.gov.au/Search/It...
# 2366  http://www.archivessearch.qld.gov.au/Search/It...
# 2367  http://www.archivessearch.qld.gov.au/Search/It...
# 2368  http://www.archivessearch.qld.gov.au/Search/It...

# %% [markdown]
# <div class="alert alert-info"><img src="../images/hhicon.png" width="50px" style="vertical-align: bottom; margin-right: 10px;">Try changing the value of the name – what about 'SMITH'? Remember to keep the quotes around the name.</div>

# %% [markdown]
# ## Find (or exclude) missing values
#
# To find all rows where `Age` is not available, we can use `.iloc` with `.isnull`.

# %%
df.loc[df['Age'].isnull()]
# Out:
#        Last name Given names  Age  No. Date of death Prev sys  Item ID  \
# 18         ADAMS       Annie  NaN  NaN    1900-10-11  HOS1/18     2887
# 19         ADAMS        Jane  NaN  NaN    1902-07-05  HOS1/18     2887
# 20         ADAMS         Reg  NaN  NaN    1913-04-03  HOS1/18     2887
# 59         AHERN     Patrick  NaN  NaN    1899-09-07  HOS1/18     2887
# 72    ALEXANDROF        Alex  NaN  NaN    1911-01-17  HOS1/18     2887
# ...          ...         ...  ...  ...           ...      ...      ...
# 4834      WRIGHT       Henry  NaN  NaN    1899-07-28  HOS1/18     2887
# 4839       WYATT      Norman  NaN  NaN    1907-03-25  HOS1/18     2887
# 4842       WYNNE        Mary  NaN  NaN    1908-09-13  HOS1/18     2887
# 4844      YARROW       Alice  NaN  NaN    1902-12-09  HOS1/18     2887
# 4860       YOUNG       Henry  NaN  NaN    1906-09-29  HOS1/18     2887
#
#      Microfilm number                          Index name  \
# 18              Z1168  Brisbane Hospital deaths 1899-1913
# 19              Z1168  Brisbane Hospital deaths 1899-1913
# 20              Z1168  Brisbane Hospital deaths 1899-1913
# 59              Z1168  Brisbane Hospital deaths 1899-1913
# 72              Z1168  Brisbane Hospital deaths 1899-1913
# ...               ...                                 ...
# 4834            Z1168  Brisbane Hospital deaths 1899-1913
# 4839            Z1168  Brisbane Hospital deaths 1899-1913
# 4842            Z1168  Brisbane Hospital deaths 1899-1913
# 4844            Z1168  Brisbane Hospital deaths 1899-1913
# 4860            Z1168  Brisbane Hospital deaths 1899-1913
#
#                                             Description  \
# 18    Registers kept by the Brisbane Hospital record...
# 19    Registers kept by the Brisbane Hospital record...
# 20    Registers kept by the Brisbane Hospital record...
# 59    Registers kept by the Brisbane Hospital record...
# 72    Registers kept by the Brisbane Hospital record...
# ...                                                 ...
# 4834  Registers kept by the Brisbane Hospital record...
# 4839  Registers kept by the Brisbane Hospital record...
# 4842  Registers kept by the Brisbane Hospital record...
# 4844  Registers kept by the Brisbane Hospital record...
# 4860  Registers kept by the Brisbane Hospital record...
#
#                                                  Source
# 18    http://www.archivessearch.qld.gov.au/Search/It...
# 19    http://www.archivessearch.qld.gov.au/Search/It...
# 20    http://www.archivessearch.qld.gov.au/Search/It...
# 59    http://www.archivessearch.qld.gov.au/Search/It...
# 72    http://www.archivessearch.qld.gov.au/Search/It...
# ...                                                 ...
# 4834  http://www.archivessearch.qld.gov.au/Search/It...
# 4839  http://www.archivessearch.qld.gov.au/Search/It...
# 4842  http://www.archivessearch.qld.gov.au/Search/It...
# 4844  http://www.archivessearch.qld.gov.au/Search/It...
# 4860  http://www.archivessearch.qld.gov.au/Search/It...
#
# [334 rows x 11 columns]

# %% [markdown]
# So there are 334 rows that don't have a value for `Age`. Note that Pandas represents a missing value as `NaN`.
#
# If we want to get all the available values for `Age` (without the `NaN`s), we can use `.dropna`.

# %%
df['Age'].dropna()
# Out:
# 0       47.0
# 1       45.0
# 2       40.0
# 3       71.0
# 4       30.0
#         ...
# 4861    43.0
# 4862    63.0
# 4863    46.0
# 4864    71.0
# 4865    44.0
# Name: Age, Length: 4532, dtype: float64

# %% [markdown]
# ## Find the youngest and oldest ages
#
# Using `.min()` and `.max()` we can find the smallest and largest values in a field.

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 96.0

# %% [markdown]
# To find the index of the row with the largest value we can use `.idxmax()`. Then we can give that value to `.iloc` to get the details of that row. So who was the 96-year-old patient?

# %%
df.loc[df['Age'].idxmin()]
# Out:
# Last name                                                        BEST
# Given names                                                  Florence
# Age                                                                 0
# No.                                                               180
# Date of death                                              1903-07-18
# Prev sys                                                      HOS1/18
# Item ID                                                          2887
# Microfilm number                                                Z1168
# Index name                         Brisbane Hospital deaths 1899-1913
# Description         Registers kept by the Brisbane Hospital record...
# Source              http://www.archivessearch.qld.gov.au/Search/It...
# Name: 307, dtype: object

# %% [markdown]
# We can even find out the mean age at death – we just use `.mean()`.

# %%
df['Age'].mean()
# Out:
# 45.18556928508385

# %% [markdown]
# <div class="alert alert-info"><img src="../images/hhicon.png" width="50px" style="vertical-align: bottom; margin-right: 10px;">A challenge! Can you use what you've learnt on this page to find all records where the age at death was recorded as 0? The answer is hidden below – click on the dots to reveal it.</div>

# %%
df.loc[df['Age'] == 0]
# Out:
#       Last name     Given names  Age    No. Date of death Prev sys  Item ID  \
# 307        BEST        Florence  0.0  180.0    1903-07-18  HOS1/18     2887
# 611      BYRNES             NaN  0.0  118.0    1905-05-20  HOS1/18     2887
# 676     CARROLL        Margaret  0.0  212.0    1899-11-21  HOS1/18     2887
# 946       CRUST             NaN  0.0  156.0    1910-07-01  HOS1/18     2887
# 999   DAUGHTREY             NaN  0.0  120.0    1901-06-19  HOS1/18     2887
# 1112    DONOVAN   Michael Denis  0.0  277.0    1912-10-24  HOS1/18     2887
# 1353   FILEWOOD             NaN  0.0    1.0    1903-01-01  HOS1/18     2887
# 1410      FOLEY             NaN  0.0  137.0    1899-07-28  HOS1/18     2887
# 1845      HAYES             NaN  0.0  343.0    1910-12-19  HOS1/18     2887
# 1901      HESSE       Maud Lucy  0.0  244.0    1901-11-24  HOS1/18     2887
# 1960   HOHRMANN   Harold Joseph  0.0  193.0    1903-08-13  HOS1/18     2887
# 2120    JACKMAN  Charles Edward  0.0   60.0    1903-03-03  HOS1/18     2887
# 2219  JOHNSTONE             NaN  0.0   97.0    1907-04-22  HOS1/18     2887
# 2365       KING             NaN  0.0  125.0    1910-06-04  HOS1/18     2887
# 2471     LAWSON             NaN  0.0  234.0    1903-10-20  HOS1/18     2887
# 2522      LEWIS             NaN  0.0   86.0    1901-04-25  HOS1/18     2887
# 2920     McLEOD             NaN  0.0  288.0    1913-10-29  HOS1/18     2887
# 2961  McTACKETT           Ralph  0.0  210.0    1900-12-23  HOS1/18     2887
# 3274      NOBLE             NaN  0.0  140.0    1912-05-13  HOS1/18     2887
# 3718   RICHARDS             NaN  0.0  121.0    1911-05-18  HOS1/18     2887
# 3983    SEYMOUR             NaN  0.0  110.0    1910-05-15  HOS1/18     2887
# 3992     SHANGE    Thomas James  0.0   18.0    1913-01-17  HOS1/18     2887
# 4159      SORBY             NaN  0.0  157.0    1899-08-21  HOS1/18     2887
# 4206     STEELE             NaN  0.0  130.0    1899-07-10  HOS1/18     2887
# 4583       WARD             NaN  0.0   73.0    1908-04-13  HOS1/18     2887
# 4609       WARR  Alfred Auguste  0.0  161.0    1909-07-02  HOS1/18     2887
# 4623    WATKINS             NaN  0.0  173.0    1906-08-31  HOS1/18     2887
#
#      Microfilm number                          Index name  \
# 307             Z1168  Brisbane Hospital deaths 1899-1913
# 611             Z1168  Brisbane Hospital deaths 1899-1913
# 676             Z1168  Brisbane Hospital deaths 1899-1913
# 946             Z1168  Brisbane Hospital deaths 1899-1913
# 999             Z1168  Brisbane Hospital deaths 1899-1913
# 1112            Z1168  Brisbane Hospital deaths 1899-1913
# 1353            Z1168  Brisbane Hospital deaths 1899-1913
# 1410            Z1168  Brisbane Hospital deaths 1899-1913
# 1845            Z1168  Brisbane Hospital deaths 1899-1913
# 1901            Z1168  Brisbane Hospital deaths 1899-1913
# 1960            Z1168  Brisbane Hospital deaths 1899-1913
# 2120            Z1168  Brisbane Hospital deaths 1899-1913
# 2219            Z1168  Brisbane Hospital deaths 1899-1913
# 2365            Z1168  Brisbane Hospital deaths 1899-1913
# 2471            Z1168  Brisbane Hospital deaths 1899-1913
# 2522            Z1168  Brisbane Hospital deaths 1899-1913
# 2920            Z1168  Brisbane Hospital deaths 1899-1913
# 2961            Z1168  Brisbane Hospital deaths 1899-1913
# 3274            Z1168  Brisbane Hospital deaths 1899-1913
# 3718            Z1168  Brisbane Hospital deaths 1899-1913
# 3983            Z1168  Brisbane Hospital deaths 1899-1913
# 3992            Z1168  Brisbane Hospital deaths 1899-1913
# 4159            Z1168  Brisbane Hospital deaths 1899-1913
# 4206            Z1168  Brisbane Hospital deaths 1899-1913
# 4583            Z1168  Brisbane Hospital deaths 1899-1913
# 4609            Z1168  Brisbane Hospital deaths 1899-1913
# 4623            Z1168  Brisbane Hospital deaths 1899-1913
#
#                                             Description  \
# 307   Registers kept by the Brisbane Hospital record...
# 611   Registers kept by the Brisbane Hospital record...
# 676   Registers kept by the Brisbane Hospital record...
# 946   Registers kept by the Brisbane Hospital record...
# 999   Registers kept by the Brisbane Hospital record...
# 1112  Registers kept by the Brisbane Hospital record...
# 1353  Registers kept by the Brisbane Hospital record...
# 1410  Registers kept by the Brisbane Hospital record...
# 1845  Registers kept by the Brisbane Hospital record...
# 1901  Registers kept by the Brisbane Hospital record...
# 1960  Registers kept by the Brisbane Hospital record...
# 2120  Registers kept by the Brisbane Hospital record...
# 2219  Registers kept by the Brisbane Hospital record...
# 2365  Registers kept by the Brisbane Hospital record...
# 2471  Registers kept by the Brisbane Hospital record...
# 2522  Registers kept by the Brisbane Hospital record...
# 2920  Registers kept by the Brisbane Hospital record...
# 2961  Registers kept by the Brisbane Hospital record...
# 3274  Registers kept by the Brisbane Hospital record...
# 3718  Registers kept by the Brisbane Hospital record...
# 3983  Registers kept by the Brisbane Hospital record...
# 3992  Registers kept by the Brisbane Hospital record...
# 4159  Registers kept by the Brisbane Hospital record...
# 4206  Registers kept by the Brisbane Hospital record...
# 4583  Registers kept by the Brisbane Hospital record...
# 4609  Registers kept by the Brisbane Hospital record...
# 4623  Registers kept by the Brisbane Hospital record...
#
#                                                  Source
# 307   http://www.archivessearch.qld.gov.au/Search/It...
# 611   http://www.archivessearch.qld.gov.au/Search/It...
# 676   http://www.archivessearch.qld.gov.au/Search/It...
# 946   http://www.archivessearch.qld.gov.au/Search/It...
# 999   http://www.archivessearch.qld.gov.au/Search/It...
# 1112  http://www.archivessearch.qld.gov.au/Search/It...
# 1353  http://www.archivessearch.qld.gov.au/Search/It...
# 1410  http://www.archivessearch.qld.gov.au/Search/It...
# 1845  http://www.archivessearch.qld.gov.au/Search/It...
# 1901  http://www.archivessearch.qld.gov.au/Search/It...
# 1960  http://www.archivessearch.qld.gov.au/Search/It...
# 2120  http://www.archivessearch.qld.gov.au/Search/It...
# 2219  http://www.archivessearch.qld.gov.au/Search/It...
# 2365  http://www.archivessearch.qld.gov.au/Search/It...
# 2471  http://www.archivessearch.qld.gov.au/Search/It...
# 2522  http://www.archivessearch.qld.gov.au/Search/It...
# 2920  http://www.archivessearch.qld.gov.au/Search/It...
# 2961  http://www.archivessearch.qld.gov.au/Search/It...
# 3274  http://www.archivessearch.qld.gov.au/Search/It...
# 3718  http://www.archivessearch.qld.gov.au/Search/It...
# 3983  http://www.archivessearch.qld.gov.au/Search/It...
# 3992  http://www.archivessearch.qld.gov.au/Search/It...
# 4159  http://www.archivessearch.qld.gov.au/Search/It...
# 4206  http://www.archivessearch.qld.gov.au/Search/It...
# 4583  http://www.archivessearch.qld.gov.au/Search/It...
# 4609  http://www.archivessearch.qld.gov.au/Search/It...
# 4623  http://www.archivessearch.qld.gov.au/Search/It...

# %% [markdown]
# Finally, let's chart the distribution of ages.

# %%
alt.Chart(df.loc[df['Age'].notnull()]).mark_bar().encode(
    alt.X("Age:Q", bin=True),
    y='count()',
    tooltip=[alt.Tooltip('Age', bin=True), 'count()']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## What format are the dates in?

# %% [markdown]
# The 'Date of death column' looks pretty consistent, with a standard ISO YYYY-MM-DD format.

# %%
df['Date of death']
# Out:
# 0       1907-06-24
# 1       1913-08-04
# 2       1907-11-19
# 3       1912-07-09
# 4       1906-11-27
#            ...
# 4861    1905-02-08
# 4862    1912-07-17
# 4863    1899-06-18
# 4864    1900-07-18
# 4865    1905-04-09
# Name: Date of death, Length: 4866, dtype: object

# %% [markdown]
# If it is as consistent as it seems, we should be able to convert these date strings in Python Datetime objects. Once again, Pandas makes this easy with the `.to_datetime` function. We'll set `errors` to 'coerce'. That means that if any dates can't be converted, they'll be given a null value.

# %%
df['date'] = pd.to_datetime(df['Date of death'], errors='coerce', utc=True)

# %% [markdown]
# Let's have a look at the results.

# %%
df['date']
# Out:
# 0      1907-06-24 00:00:00+00:00
# 1      1913-08-04 00:00:00+00:00
# 2      1907-11-19 00:00:00+00:00
# 3      1912-07-09 00:00:00+00:00
# 4      1906-11-27 00:00:00+00:00
#                   ...
# 4861   1905-02-08 00:00:00+00:00
# 4862   1912-07-17 00:00:00+00:00
# 4863   1899-06-18 00:00:00+00:00
# 4864   1900-07-18 00:00:00+00:00
# 4865   1905-04-09 00:00:00+00:00
# Name: date, Length: 4866, dtype: datetime64[ns, UTC]

# %% [markdown]
# Looks like the strings were successfully converted to dates, but were there any problems. Let's check the null values.

# %%
df.loc[df['date'].isnull()]
# Out:
#      Last name Given names  Age  No. Date of death Prev sys  Item ID  \
# 144     ASHTON       Daisy  NaN  NaN           NaN  HOS1/18     2887
# 3380   OGILVIE      Hannah  NaN  NaN        Apr-08  HOS1/18     2887
#
#      Microfilm number                          Index name  \
# 144             Z1168  Brisbane Hospital deaths 1899-1913
# 3380            Z1168  Brisbane Hospital deaths 1899-1913
#
#                                             Description  \
# 144   Registers kept by the Brisbane Hospital record...
# 3380  Registers kept by the Brisbane Hospital record...
#
#                                                  Source date
# 144   http://www.archivessearch.qld.gov.au/Search/It...  NaT
# 3380  http://www.archivessearch.qld.gov.au/Search/It...  NaT

# %% [markdown]
# So two rows had bad dates – one was missing, and one was in a non-standard format. Let's create a chart to view the results. First we'll reorganise the data a bit to get the total number of deaths per year.

# %%
deaths_by_year = df['date'].dt.year.value_counts().to_frame().reset_index()
deaths_by_year.columns = ['year', 'deaths']
deaths_by_year['year'] = deaths_by_year['year'].astype(int)
deaths_by_year.head()
# Out:
#    year  deaths
# 0  1913     389
# 1  1912     377
# 2  1910     370
# 3  1911     366
# 4  1909     350

# %% [markdown]
# Then we'll build the chart.

# %%
alt.Chart(deaths_by_year).mark_bar().encode(
    x='year:N',
    y='deaths:Q',
    tooltip=['year:N', 'deaths']
).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## What's next?

# %% [markdown]
# Using this notebook as a template, try exploring the size and shape of a different CSV file. There's plenty to choose from in this [GLAM data list](https://glam-workbench.github.io/glam-datasets-from-gov-portals/). Copy the url of the CSV file and paste it into the `.read_csv()` cell at the top. Of course, the column names are likely to be different, so you'll have to adjust them to suit.
